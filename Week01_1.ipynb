# %%
import this

# %%
import yfinance as yf
import mplfinance as mpf
stock = yf.download("TSLA", "2022-08-01", "2023-09-12")
mpf.plot(stock, type="candle", mav=(5, 10), volume=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# asdjsadjjlkd dsadaskl;ds;ldsa;k
1 + 1 # asdasdasdsadsas
# Out:
# 2

# %% [markdown]
# some text
#
#
# some more text
#
#
# **this is a bold font**
#
# *italic*
#
# ***wow***

# %%
1 +
1
# Out:
#   Cell In [8], line 1
#     1 +
#        ^
# SyntaxError: invalid syntax

# %%
1 + (1 +
     1)
# Out:
# 3

# %%
1
- 2
# Out:
# -2

# %%
print('Hello world!'); print("something else")
# Out:
# Hello world!
# something else

# %%
print(5**10234)
# Out:
# ...

# %%
print(2^2) #XOR
# Out:
# 0

# %%
0.000000001 / 100000000
# Out:
# 1e-17

# %%
x = 1
x
# Out:
# 1

# %%
x = x + 45
x
# Out:
# 46

# %%
xX1_ = 5
xX1_
# Out:
# 5

# %%
1x = 7
# Out:
#   Cell In [26], line 1
#     1x = 7
#      ^
# SyntaxError: invalid syntax

# %%
_x1 = 5

# %%
_x1
# Out:
# 5

# %%
a, b = 1, 7

# %%
a
# Out:
# 1

# %%
b
# Out:
# 7

# %%
print(a, b)
# Out:
# 1 7

# %%
type(a)
a = 1.5
type(a)
type(True)
type(False)
type(None)
type((-1)**(1 / 2))
# Out:
# complex

# %%
price = 300
print("The price is " + str(price) + " dollars")
# Out:
# The price is 300 dollars

# %%
"Hello"*5
# Out:
# 'HelloHelloHelloHelloHello'

# %%
int(34.4)
int("34.4")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [45], line 2
#       1 int(34.4)
# ----> 2 int("34.4")
#
# ValueError: invalid literal for int() with base 10: '34.4'

# %%
x = [1, 2, 3,4]

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
len(x)
# Out:
# 4

# %%
type(x)
# Out:
# list

# %%
x[1]
# Out:
# 2

# %%
x[0]
# Out:
# 1

# %%
x[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [52], line 1
# ----> 1 x[7]
#
# IndexError: list index out of range

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
x[-3]
# Out:
# 2

# %%
x = [3432, 32423, 45353453, 123123123]
x
# Out:
# [3432, 32423, 45353453, 123123123]

# %%
x[1:3]
# Out:
# [32423, 45353453]

# %%
x[:2]
# Out:
# [3432, 32423]

# %%
x[2:]
# Out:
# [45353453, 123123123]

# %%
x[1:30]
# Out:
# [32423, 45353453, 123123123]

# %%
x[0:6:2]
# Out:
# [3432, 45353453]

# %%
x
# Out:
# [3432, 32423, 45353453, 123123123]

# %%
x = [1, 2, 3]
y = x
print(y)
print(x)

y[2] = 10000
print(y)
print(x)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 10000]
# [1, 2, 10000]

# %% [markdown]
# y -> x -> [1, 2, 3]

# %%
x = [1, 2, 3]
y = x.copy()
print(y)
print(x)

y[2] = 10000
print(y)
print(x)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 10000]
# [1, 2, 3]

# %%
x.reverse()

# %%
x
# Out:
# [3, 2, 1]

# %%
x = 5

# %%
x.real
# Out:
# 5

# %%
# !pip3 install yfinance
