# %%
import pandas as pd
import numpy as np
import os

# %%
sp500 = pd.read_csv("http://glebvasiliev.com/sp500.csv")

# %%
os.getcwd()
# Out:
# '/Users/gleb/Library/Mobile Documents/com~apple~CloudDocs/ThePythonCourse2023'

# %%
sp500
#sp500.info()
sp500.describe()
sp500
# Out:
#     ticker  previousClose  regularMarketOpen  twoHundredDayAverage  \
# 0      MMM         150.26             148.44             155.31915
# 1      AOS          64.33              63.67              68.56645
# 2      ABT         112.03             111.63             120.03330
# 3     ABBV         142.55             141.42             142.81995
# 4      ACN         320.78             317.42             327.39530
# ..     ...            ...                ...                   ...
# 440    XYL         103.96             102.79              96.64595
# 441    YUM         119.04             117.56             121.69080
# 442    ZBH         116.12             115.23             119.23954
# 443   ZION          58.58              57.84              61.41240
# 444    ZTS         171.79             171.70             192.87660
#
#      trailingAnnualDividendYield  payoutRatio  regularMarketDayHigh  \
# 0                       0.039531       0.8296              148.7900
# ...

# %%
sp500.sort_values(["industry", "payoutRatio"], ascending=[True, False])
# Out:
#     ticker  previousClose  regularMarketOpen  twoHundredDayAverage  \
# 307    OMC          73.68              73.01              74.12890
# 219    IPG          30.70              30.44              33.55985
# 249    LMT         440.16             436.13             403.27880
# 179     GD         241.48             239.64             220.05025
# 209    HII         233.54             231.64             201.87485
# ..     ...            ...                ...                   ...
# 296     NI          31.58              31.55              28.77345
# 33     AWK         159.50             159.10             159.41914
# 426     WM         174.81             174.29             156.97420
# 350    RSG         147.12             146.67             131.56735
# 375   SRCL          55.04              54.49              54.06755
#
#      trailingAnnualDividendYield  payoutRatio  regularMarketDayHigh  \
# 307                     0.038002       0.4583                73.135
# ...

# %%
sp500["signalOne"] = np.where(sp500["previousClose"] < sp500["twoHundredDayAverage"],
                              "buy", "-")
sp500
sp500.sort_values(["industry", "payoutRatio"], ascending=[True, False])
#sp500 = sp500.sort_values(["industry", "payoutRatio"], ascending=[True, False])
#sp500.sort_values(["industry", "payoutRatio"], ascending=[True, False], inplace=True)
sp500

#incorrect: sp500.signalttrtr = np.where(sp500["previousClose"] < sp500["twoHundredDayAverage"],"buy", "-")

sp500 = sp500.assign(signalOne = np.where(sp500["previousClose"] < sp500["twoHundredDayAverage"],
                              "buy", "-"),
            signalTwo = np.where(sp500["previousClose"] < sp500["fiftyDayAverage"],
                              "buy", "-"))

# %%
sp500.query("signalOne == 'buy' & signalTwo == 'buy'")
sp500.query("signalOne == 'buy' | signalTwo == 'buy'")
sp500.query("ticker in ['ABBV', 'MMM']")
sp500.query("ticker not in ['ABBV', 'MMM']")
sp500.query("ticker == ['ABBV', 'MMM']")
sp500.query("index > 100")
# Out:
#     ticker  previousClose  regularMarketOpen  twoHundredDayAverage  \
# 101   CTSH          69.94              69.44              79.84595
# 102     CL          82.18              82.05              78.92290
# 103  CMCSA          40.36              39.98              45.86345
# 104    CMA          86.51              85.35              85.70930
# 105    CAG          35.24              35.24              33.74275
# ..     ...            ...                ...                   ...
# 440    XYL         103.96             102.79              96.64595
# 441    YUM         119.04             117.56             121.69080
# 442    ZBH         116.12             115.23             119.23954
# 443   ZION          58.58              57.84              61.41240
# 444    ZTS         171.79             171.70             192.87660
#
#      trailingAnnualDividendYield  payoutRatio  regularMarketDayHigh  \
# 101                     0.015013       0.2367                69.810
# ...

# %%
sp500.drop("signalOne", axis=1)
sp500
sp500.drop_duplicates("industry").sort_values("industry")
sp500.drop_duplicates("industry").sort_values("industry").rename(columns={"signalOne":"mainSignal"})
# Out:
#     ticker  previousClose  regularMarketOpen  twoHundredDayAverage  \
# 219    IPG          30.70              30.44              33.55985
# 65      BA         172.08             169.61             178.67930
# 83      CF         103.23             102.85              83.88945
# 16     ALK          48.24              47.28              50.61465
# 190    HBI          11.16              10.97              14.23090
# ..     ...            ...                ...                   ...
# 302    NRG          42.60              42.23              39.25855
# 21     LNT          64.06              63.82              59.39325
# 296     NI          31.58              31.55              28.77345
# 33     AWK         159.50             159.10             159.41914
# 350    RSG         147.12             146.67             131.56735
#
#      trailingAnnualDividendYield  payoutRatio  regularMarketDayHigh  \
# 219                     0.036482       0.4516               30.5800
# ...

# %% [markdown]
# ### Heading 3
# ## Heading 2 (Spotify Data)
#
# **this is a new part**
#
# Let's analyse Spotify data.

# %%
spotify = pd.read_csv("http://glebvasiliev.com/spotify23.csv", encoding="latin-1")

# %%
spotify
#spotify.info()
spotify.describe()
spotify
spotify[spotify.artist_names.str.contains("Dua Lipa")]
spotify.query("artist_names.str.contains('Dua Lipa')")
spotify.query("danceability > 90 | energy > 90")

spotify.set_index("track_name")
#spotify = pd.read_csv("http://glebvasiliev.com/spotify23.csv", encoding="latin-1", index_col="track_name")
# Out:
#                                            artist_names  artist_count  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# LALA                                        Myke Towers             1
# vampire                                  Olivia Rodrigo             1
# Cruel Summer                               Taylor Swift             1
# WHERE SHE GOES                                Bad Bunny             1
# ...                                                 ...           ...
# My Mind & Me                               Selena Gomez             1
# Bigger Than The Whole Sky                  Taylor Swift             1
# A Veces (feat. Feid)                 Feid, Paulo Londra             2
# En La De Ella                        Feid, Sech, Jhayco             3
# Alone                                         Burna Boy             1
#
#                                      released_year  released_month  \
# track_name
# ...

# %%
spotify.reset_index()
spotify.reset_index(inplace=True)

# %%
spotify = spotify.set_index("track_name")

# %%
spotify
spotify.reset_index(inplace=True)
spotify
# Out:
#                               track_name  index        artist_names  \
# 0    Seven (feat. Latto) (Explicit Ver.)      0    Latto, Jung Kook
# 1                                   LALA      1         Myke Towers
# 2                                vampire      2      Olivia Rodrigo
# 3                           Cruel Summer      3        Taylor Swift
# 4                         WHERE SHE GOES      4           Bad Bunny
# ..                                   ...    ...                 ...
# 948                         My Mind & Me    948        Selena Gomez
# 949            Bigger Than The Whole Sky    949        Taylor Swift
# 950                 A Veces (feat. Feid)    950  Feid, Paulo Londra
# 951                        En La De Ella    951  Feid, Sech, Jhayco
# 952                                Alone    952           Burna Boy
#
#      artist_count  released_year  released_month  released_day  \
# 0               2           2023               7            14
# ...

# %%
spotify.reset_index(inplace=True)

# %%
spotify.reset_index(inplace=True) #error!
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [58], line 1
# ----> 1 spotify.reset_index(inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5848, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill)
#    5842         if lab is not None:
#    5843             # if we have the codes, extract the values with a mask
#    5844             level_values = algorithms.take(
# ...

# %%
spotify
# Out:
#      level_0                           track_name  index        artist_names  \
# 0          0  Seven (feat. Latto) (Explicit Ver.)      0    Latto, Jung Kook
# 1          1                                 LALA      1         Myke Towers
# 2          2                              vampire      2      Olivia Rodrigo
# 3          3                         Cruel Summer      3        Taylor Swift
# 4          4                       WHERE SHE GOES      4           Bad Bunny
# ..       ...                                  ...    ...                 ...
# 948      948                         My Mind & Me    948        Selena Gomez
# 949      949            Bigger Than The Whole Sky    949        Taylor Swift
# 950      950                 A Veces (feat. Feid)    950  Feid, Paulo Londra
# 951      951                        En La De Ella    951  Feid, Sech, Jhayco
# 952      952                                Alone    952           Burna Boy
#
# ...

# %%
spotify.index = spotify["track_name"]

# %%
spotify.set_index(["artist_names", "key"], drop=False, append=True, inplace=True)
spotify
# Out:
#                                                             level_0  \
# track_name                          artist_names       key
# Seven (feat. Latto) (Explicit Ver.) Latto, Jung Kook   B          0
# LALA                                Myke Towers        C#         1
# vampire                             Olivia Rodrigo     F          2
# Cruel Summer                        Taylor Swift       A          3
# WHERE SHE GOES                      Bad Bunny          A          4
# ...                                                             ...
# My Mind & Me                        Selena Gomez       A        948
# Bigger Than The Whole Sky           Taylor Swift       F#       949
# A Veces (feat. Feid)                Feid, Paulo Londra C#       950
# En La De Ella                       Feid, Sech, Jhayco C#       951
# Alone                               Burna Boy          E        952
#
# ...

# %%
spotify.loc["Alone"]
spotify.loc[["Alone"]]
# Out:
#                              level_0 track_name  index artist_names  \
# track_name artist_names key
# Alone      Burna Boy    E        952      Alone    952    Burna Boy
#
#                              artist_count  released_year  released_month  \
# track_name artist_names key
# Alone      Burna Boy    E               1           2022              11
#
#                              released_day  in_spotify_playlists  \
# track_name artist_names key
# Alone      Burna Boy    E               4                   782
#
#                              in_spotify_charts  ... bpm  key   mode  \
# track_name artist_names key                     ...
# Alone      Burna Boy    E                    2  ...  90    E  Minor
#
#                             danceability  valence energy  acousticness  \
# track_name artist_names key
# Alone      Burna Boy    E             61       32     67            15
#
#                             instrumentalness liveness  speechiness
# ...

# %%
spotify.loc[("Alone", "Burna Boy", "E")]
# Out:
# /var/folders/rh/h38wf26j7bx6gw3hl1s3v3l00000gn/T/ipykernel_6514/2554647706.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   spotify.loc[("Alone", "Burna Boy", "E")]
#                              level_0 track_name  index artist_names  \
# track_name artist_names key
# Alone      Burna Boy    E        952      Alone    952    Burna Boy
#
#                              artist_count  released_year  released_month  \
# track_name artist_names key
# Alone      Burna Boy    E               1           2022              11
#
#                              released_day  in_spotify_playlists  \
# track_name artist_names key
# Alone      Burna Boy    E               4                   782
#
#                              in_spotify_charts  ... bpm  key   mode  \
# track_name artist_names key                     ...
# Alone      Burna Boy    E                    2  ...  90    E  Minor
#
# ...

# %%
spotify.sort_index().loc[("Alone", "Burna Boy", "E")]
# Out:
#                              level_0 track_name  index artist_names  \
# track_name artist_names key
# Alone      Burna Boy    E        952      Alone    952    Burna Boy
#
#                              artist_count  released_year  released_month  \
# track_name artist_names key
# Alone      Burna Boy    E               1           2022              11
#
#                              released_day  in_spotify_playlists  \
# track_name artist_names key
# Alone      Burna Boy    E               4                   782
#
#                              in_spotify_charts  ... bpm  key   mode  \
# track_name artist_names key                     ...
# Alone      Burna Boy    E                    2  ...  90    E  Minor
#
#                             danceability  valence energy  acousticness  \
# track_name artist_names key
# Alone      Burna Boy    E             61       32     67            15
#
#                             instrumentalness liveness  speechiness
# ...

# %%
spotify.sort_index().loc["10 Things I Hate About You":"you broke me first"]
#spotify.loc["10 Things I Hate About You":"you broke me first"]
spotify.sort_index().loc[(slice(None),slice("Leah Kate", "Lewis Capaldi"),slice(None)), :] #unexpected result!
spotify.sort_index().loc[("10 Things I Hate About You", "Leah Kate", "G#"):("Zona De Perigo", "Leo Santana", "F")]
# Out:
#                                                      level_0  \
# track_name                 artist_names         key
# 10 Things I Hate About You Leah Kate            G#       817
# 10:35                      Tiï¿½ï¿½sto, Tate M  G#       303
# 2 Be Loved (Am I Ready)    Lizzo                G        924
# 2055                       Sleepy hallow        F#       607
# 212                        Mainstreet, Chefin   D        678
# ...                                                      ...
# You Proof                  Morgan Wallen        A        316
# You Right                  Doja Cat, The Weeknd G#       564
# You're On Your Own, Kid    Taylor Swift         D        437
# ZOOM                       Jessi                F#       814
# Zona De Perigo             Leo Santana          F        359
#
#                                                                      track_name  \
# track_name                 artist_names         key
# ...

# %%
spotify
spotify.reorder_levels([2, 0, 1], axis=0)
# Out:
#                                                             level_0  \
# key track_name                          artist_names
# B   Seven (feat. Latto) (Explicit Ver.) Latto, Jung Kook          0
# C#  LALA                                Myke Towers               1
# F   vampire                             Olivia Rodrigo            2
# A   Cruel Summer                        Taylor Swift              3
#     WHERE SHE GOES                      Bad Bunny                 4
# ...                                                             ...
#     My Mind & Me                        Selena Gomez            948
# F#  Bigger Than The Whole Sky           Taylor Swift            949
# C#  A Veces (feat. Feid)                Feid, Paulo Londra      950
#     En La De Ella                       Feid, Sech, Jhayco      951
# E   Alone                               Burna Boy               952
#
# ...
